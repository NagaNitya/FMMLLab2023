# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaNitya/FMMLLab2023/blob/labs/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 15:21:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   190MB/s    in 0.4s
#
# 2024-03-31 15:21:16 (190 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10242  1803.05752v1  Rearranging objects on a tabletop surface by m...    cs
# 12253  1710.10793v1  Generative Adversarial Networks (GANs) have be...  stat
# 24191   1003.1891v1  Handwritten numeral recognition is in general ...    cs
# 22947  1711.07527v1  Inpatient care is a large share of total healt...  stat
# 13508   1406.2613v1  Studies have shown that multi-objective optimi...    cs
# ...             ...                                                ...   ...
# 30256  1711.10069v2  Most of the correlation filter based tracking ...    cs
# 22391  1605.05918v2  Sparse versions of principal component analysi...  stat
# 73     1603.08023v2  We investigate evaluation metrics for dialogue...    cs
# 28969  1708.01566v1  The success of deep learning in computer visio...    cs
# 32992  1512.06900v1  Embedding learning, a.k.a. representation lear...    cs
#
#                                                    title  year  \
# 10242  Rearrangement with Nonprehensile Manipulation ...  2018
# 12253                Understanding GANs: the LQG Setting  2017
# 24191  Handwritten Arabic Numeral Recognition using a...  2010
# 22947  Subgroup Identification and Interpretation wit...  2017
# 13508  Simulation based Hardness Evaluation of a Mult...  2014
# ...                                                  ...   ...
# 30256  Particle Filter Re-detection for Visual Tracki...  2017
# 22391  Bayesian Variable Selection for Globally Spars...  2016
# 73     How NOT To Evaluate Your Dialogue System: An E...  2016
# 28969  Augmented Reality Meets Computer Vision : Effi...  2017
# 32992  Predicting the Co-Evolution of Event and Knowl...  2015
#
#                                                 keywords
# 10242  [rearranging, nonprehensile, manipulation, int...
# 12253  [generative, adversarial, probability, archite...
# 24191  [handwritten, recognition, benchmark, recognit...
# 22947  [inpatient, inpatient, utilization, important,...
# 13508  [objective, optimization, researchers, increas...
# ...                                                  ...
# 30256  [correlation, algorithms, performance, computa...
# 22391  [principal, component, themselves, selecting, ...
# 73     [investigate, evaluation, generation, supervis...
# 28969  [availability, annotated, virtually, popularit...
# 32992  [embedding, representation, knowledge, knowled...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10242    [rearranging, nonprehensile, manipulation, int...
# 12253    [generative, adversarial, probability, archite...
# 24191    [handwritten, recognition, benchmark, recognit...
# 22947    [inpatient, inpatient, utilization, important,...
# 13508    [objective, optimization, researchers, increas...
#                                ...
# 5162     [sometimes, described, dictionary, represented...
# 34533    [characteristics, depending, additional, knowl...
# 22718    [efficient, randomized, dimensionality, reduct...
# 6333     [efficient, algorithm, collaborative, preferen...
# 19845    [relational, diagnosis, description, associati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8884 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0504c06c-2489-4fcf-8cea-bfcd4a58fee5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0504c06c-2489-4fcf-8cea-bfcd4a58fee5")) {                    Plotly.newPlot(                        "0504c06c-2489-4fcf-8cea-bfcd4a58fee5",                        [{"x":["manipulation","environment","precisely","suboptimal","simulation","heuristic","properties","uncertainties","experience","collisions","reinforcement","performance","demonstrate","potential","exploration","explicitly","empirical","interaction","introduced","specifying","generalization","generator","optimization","different","exponentially","converges","generative","adversarial","dimension","proposing","increases","architecture","quadratic","principal","probability","architectures","connection","discriminators","constrained","supervised","generators","surrounding","distribution","discriminator","component","population","understanding","experimentation","compounded","recognition","considering","represent","represented","handwritten","applications","validation","artificial","throughout","developed","technique","evaluated","addressed","portuguese","characters","benchmark","intelligence","variations","perceptron","classifier","interpretation","treatment","clustering","dispersion","accommodate","complicate","relationships","utilization","inpatient","important","subgroups","covariates","framework","components","variances","identification","determine","inflation","differences","nonparametric","statistical","themselves","experiments","researchers","crossover","functions","increased","solutions","algorithm","evaluation","generations","usability","generation","individually","objective","objectives","quantifying","individual","evolution","increasing","offspring","incompatibility","algorithms","challenging","competing","dominated","performed","maximized","condition","regularized","dependent","projection","regularity","regression","attainable","proportional","logarithmic","byproduct","effective","saturation","convergence","assumption","combining","reproducing","randomized","hypothesis","investigate","decisions","sequential","adversarys","learnable","equivalence","reasonable","completely","scenarios","symmetrization","immediately","stochastic","classical","variation","learnability","complexity","adversary","assumptions","rademacher","variables","unfortunately","theoretical","therefore","formulation","restricted","adversaries","instances","thresholding","considered","adjacency","subspaces","correlations","incompletely","furthermore","neighbors","dimensions","robustness","constructed","synthetic","specifically","orientations","numerical","dimensional","spherical","intersect","estimation","locations","integrated","extremely","reconstruction","outperforming","probabilistic","convolutional","approaches","plausible","knowledge","efficient","intuition","classification","cooperative","determined","appearance","complicated","minimizing","enlarging"],"y":[20,110,22,10,84,56,216,12,35,3,118,871,561,153,51,59,144,86,120,4,95,23,303,712,22,27,97,91,48,21,52,239,29,40,184,118,34,5,55,201,12,16,200,13,111,48,155,14,1,383,69,91,89,27,402,51,155,21,208,242,144,37,5,36,218,98,83,20,143,66,32,122,2,9,2,64,18,0,363,2,0,543,98,7,94,69,1,44,18,154,14,608,70,8,214,39,132,795,260,3,9,104,16,160,37,9,111,67,116,3,2,572,277,26,9,140,3,40,50,95,36,5,116,2,15,16,3,227,3,116,65,120,6,25,58,137,57,77,1,14,23,30,31,76,3,6,124,87,52,5,237,6,61,7,118,36,163,150,84,44,4,98,23,130,5,20,22,1,166,19,22,111,56,143,143,8,93,161,5,1,209,43,56,47,104,31,156,394,414,26,363,402,21,501,8,37,75,37,52,2],"type":"bar"},{"x":["manipulation","environment","precisely","suboptimal","simulation","heuristic","properties","uncertainties ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Cluster</span> <span style=''>Cumulant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Expansion</span> <span style=''>at</span> <span style=''>the</span> <span style=''>Fixed</span> <span style=''>Points</span> <span style=''>of</span> <span style=''>Belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>cluster</span> <span style=''>cumulant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>(CCE)</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>fixed</span> <span style=''>points</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(IBP)</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>is</span> <span style=''>similar</span> <span style=''>in</span> <span style=''>spirit</span> <span style=''>to</span> <span style=''>the</span> <span style=''>loop</span> <span style=''>series</span> <span style=''>(LS)</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>1</span> <span style=''>However</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>the</span> <span style=''>CCE</span> <span style=''>enjoys</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>qualities</span> <span style=''>1)</span> <span style=''>it</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>2)</span> <span style=''>it</span> <span style=''>is</span> <span style=''>easily</span> <span style=''>extended</span> <span style=''>to</span> <span style=''>fixed</span> <span style=''>points</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(GBP)</span> <span style=''>3)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disconnected</span> <span style=''>groups</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3773087071240106);'>variables</span> <span style=''>will</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.48936170212765956);'>contribute</span> <span style=''>to</span> <span style=''>the</span> <span style=''>CCE</span> <span style=''>and</span> <span style=''>4)</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style=''>LS</span> <span style=''>The</span> <span style=''>CCE</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>same</span> <span style=''>Mobius</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transform</span> <span style=''>as</span> <span style=''>the</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Near</span> <span style=''>Optimal</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Multi</span> <span style=''>Output</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>output</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(MOGP)</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>multiple</span> <span style=''>types</span> <span style=''>of</span> <span style=''>coexisting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environmental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomena</span> <span style=''>In</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>existing</span> <span style=''>works</span> <span style=''>our</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>involves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>not</span> <span style=''>just</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>to</span> <span style=''>be</span> <span style=''>observed</span> <span style=''>but</span> <span style=''>also</span> <span style=''>the</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>at</span> <span style=''>each</span> <span style=''>selected</span> <span style=''>location</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>(ie</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>joint</span> <span style=''>entropy)</span> <span style=''>of</span> <span style=''>a</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomenon</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>given</span> <span style=''>a</span> <span style=''>sampling</span> <span style=''>budget</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unfortunately</span> <span style=''>such</span> <span style=''>an</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>scales</span> <span style=''>poorly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>numbers</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>and</span> <span style=''>selected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>To</span> <span style=''>resolve</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>we</span> <span style=''>first</span> <span style=''>exploit</span> <span style=''>a</span> <span style='bac ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>via</span> <span style=''>Primal</span> <span style=''>Dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Subgradient</span> <span style=''>Methods</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lagrangian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Perspective</span> <span style=''>on</span> <span style=''>GAN</span> <br/><br/><span style=''>We</span> <span style=''>relate</span> <span style=''>the</span> <span style=''>minimax</span> <span style=''>game</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>networks</span> <span style=''>(GANs)</span> <span style=''>to</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Lagrangian</span> <span style=''>function</span> <span style=''>for</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminator</span> <span style=''>outputs</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generator</span> <span style=''>outputs</span> <span style=''>play</span> <span style=''>the</span> <span style=''>roles</span> <span style=''>of</span> <span style=''>primal</span> <span style='background-color:rgba(255, 0, 0, 0.3773087071240106);'>variables</span> <span style=''>and</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3773087071240106);'>variables</span> <span style='background-color:rgba(0, 255, 0, 0.3949579831932773);'>respectively</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>shows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>between</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>GAN</span> <span style=''>training</span> <span style=''>process</span> <span style=''>and</span> <span style=''>the</span> <span style=''>primal</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subgradient</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>The</span> <span style=''>inherent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>does</span> <span style=''>not</span> <span style=''>only</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3093220338983051);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3446327683615819);'>convergence</span> <span style=''>proof</span> <span style=''>for</span> <span style=''>training</span> <span style=''>GANs</span> <span style=''>in</span> <span style=''>the</span> <span style=''>function</span> <span style=''>space</span> <span style=''>but</span> <span style=''>also</span> <span style=''>inspires</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>for</span> <span style=''>training</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Multilabel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>with</span> <span style=''>R</span> <span style=''>Package</span> <span style=''>mlr</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilabel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>the</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>package</span> <span style=''>mlr</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relevance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>chains</span> <span style=''>nested</span> <span style=''>stacking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relevance</span> <span style=''>and</span> <span style=''>stacking</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>with</span> <span style=''>any</span> <span style=''>base</span> <span style=''>learner</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accessible</span> <span style=''>in</span> <span style=''>mlr</span> <span style=''>Moreover</span> <span style=''>there</span> <span style=''>is</span> <span style=''>access</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilabel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>randomForestSRC</span> <span style=''>and</span> <span style=''>rFerns</span> <span style=''>All</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>compared</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilabel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measures</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resampling</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>standardized</span> <span style=''>mlr</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>In</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>with</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilabel</span> <span style=''>datasets</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>methods</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09946140035906642)
# 	architecture (0.08581687612208258)
# 	knowledge (0.13034111310592458)
# 	segmentation (0.0732495511669659)
# 	representation (0.13357271095152604)
# 	detection (0.1170556552962298)
# 	information (0.2481149012567325)
# 	different (0.2556552962298025)
# 	recognition (0.13752244165170557)
# 	convolutional (0.1414721723518851)
#
# Some Statistics words are:
# 	stochastic (0.13200992555831265)
# 	statistical (0.143424317617866)
# 	estimation (0.16774193548387098)
# 	algorithms (0.2997518610421836)
# 	theoretical (0.1533498759305211)
# 	algorithm (0.38858560794044666)
# 	distribution (0.1826302729528536)
# 	inference (0.1900744416873449)
# 	regression (0.1687344913151365)
# 	dimensional (0.18511166253101738)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d167cad-138b-4028-946f-6d1a57363133" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d167cad-138b-4028-946f-6d1a57363133")) {                    Plotly.newPlot(                        "0d167cad-138b-4028-946f-6d1a57363133",                        [{"x":["manipulation","environment","precisely","suboptimal","simulation","heuristic","properties","uncertainties","experience","collisions","reinforcement","performance","demonstrate","potential","exploration","explicitly","empirical","interaction","introduced","specifying","generalization","generator","optimization","different","exponentially","converges","generative","adversarial","dimension","proposing","increases","architecture","quadratic","principal","probability","architectures","connection","discriminators","constrained","supervised","generators","surrounding","distribution","discriminator","component","population","understanding","experimentation","compounded","recognition","considering","represent","represented","handwritten","applications","validation","artificial","throughout","developed","technique","evaluated","addressed","portuguese","characters","benchmark","intelligence","variations","perceptron","classifier","interpretation","treatment","clustering","dispersion","accommodate","complicate","relationships","utilization","inpatient","important","subgroups","covariates","framework","components","variances","identification","determine","inflation","differences","nonparametric","statistical","themselves","experiments","researchers","crossover","functions","increased","solutions","algorithm","evaluation","generations","usability","generation","individually","objective","objectives","quantifying","individual","evolution","increasing","offspring","incompatibility","algorithms","challenging","competing","dominated","performed","maximized","condition","regularized","dependent","projection","regularity","regression","attainable","proportional","logarithmic","byproduct","effective","saturation","convergence","assumption","combining","reproducing","randomized","hypothesis","investigate","decisions","sequential","adversarys","learnable","equivalence","reasonable","completely","scenarios","symmetrization","immediately","stochastic","classical","variation","learnability","complexity","adversary","assumptions","rademacher","variables","unfortunately","theoretical","therefore","formulation","restricted","adversaries","instances","thresholding","considered","adjacency","subspaces","correlations","incompletely","furthermore","neighbors","dimensions","robustness","constructed","synthetic","specifically","orientations","numerical","dimensional","spherical","intersect","estimation","locations","integrated","extremely","reconstruction","outperforming","probabilistic","convolutional","approaches","plausible","knowledge","efficient","intuition","classification","cooperative","determined","appearance","complicated","minimizing","enlarging","normalized","representative","measuring","reference","experimental","alleviating","implemented","distinction","recognizing","similarity","experimentally","iteration","considerably","predictors","scalability","selection","previously","techniques","embeddings","transfers","corresponding","embedding","injecting","challenge","efficiently","replacing","iteratively","observation","decreased","generated","iterative","perturbation","outperforms","reliability","challenges","computational","counterpart","pathological","annotated","respectively","coefficient","automatic","indicates","volumetric","resources","segmentation","information","structured","fragmentation","relational","prominent","hierarchical","connectivity","predictive","analyzing","simulated","pa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inpatient
# 	covariates
# 	fragmentation
# 	reversing
# 	regressive
# 	precisions
# 	asymptotics
# 	hypernetworks
# 	hypernetwork
# 	majorizer
# 	assertion
# 	initializes
# 	elliptical
# 	colorectal
# 	infection
# 	maximisation
# 	unavoidably
# 	scoresearch
# 	andersson
# 	ancillary
# Some words which never appear in Statistics papers:
# 	manipulation
# 	offspring
# 	incompatibility
# 	enlarging
# 	sentential
# 	prepositional
# 	participant
# 	adaptable
# 	substance
# 	terminates
# 	surrounded
# 	continued
# 	inheritance
# 	multidisciplinary
# 	marginalizes
# 	organizations
# 	developer
# 	promotional
# 	businesses
# 	paraphrase

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085943527233452e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7808333333333334
